# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "3"  # 使 GPU 0 和 1 可见
import logging
import numpy as np
import sys
import torch
import torch.nn as nn
import pytorch_lightning as pl
from pathlib import Path
from typing import Callable, Optional, Sequence, Union
from pymoo.indicators.gd import GD
from pymoo.indicators.gd_plus import GDPlus
from pymoo.indicators.igd import IGD
from pymoo.indicators.igd_plus import IGDPlus
from matplotlib import pyplot as plt

BASE_PATH = os.path.join(
   '/home/tzhouaq/offline-moo/'
)
sys.path.append(BASE_PATH)
CONDITIONAL_TASKS = []
# sys.path.append(os.path.join(BASE_PATH, 'off_moo_baselines'))
import off_moo_bench as ob
sys.path.append(os.path.join(BASE_PATH, 'off_moo_baselines'))
from mo_solver.ddom.design_baselines.diff.trainer import RvSDataModule
from mo_solver.ddom.design_baselines.diff.nets import (
    DiffusionTest, DiffusionScore, Swish
)
from mo_solver.ddom.design_baselines.diff.lib.sdes import (
    PluginReverseSDE, VariancePreservingSDE, UnconditionPluginReverseSDE
)
from mo_solver.ddom.design_baselines.diff.forward import ForwardModel
from utils import set_seed
# Out:
# Auto Configuration Succeed!, Using database /home/tzhouaq/offline-moo/off_moo_bench/problem/mo_nas/database.
# Configuration Succeed!
# Auto Configuration Succeed!, Using database /home/tzhouaq/offline-moo/off_moo_bench/problem/mo_nas/database.

# %%
from utils import process_args 
sys.argv = ['--model=MOBO', '--train_mode=Vallina','--task=re31','--use_wandb=False','--n_epochs=10','--retrain_model=False','--seed=1000']
config = process_args(return_dict=True)
# Out:
# All config: {'results_dir': './results', 'model_save_dir': './model', 'use_wandb': False, 'run_type': 'train', 'seed': 1000, 'retrain_model': False, 'num_solutions': 256, 'solver_n_gen': 50, 'solver_init_method': 'nds', 'model': 'MOBO', 'train_mode': 'Vallina', 'task': 're31', 'n_epochs': 10, 'data_pruning': False, 'permutation_n_gen': 200, 'sequence_n_gen': 200, 'train_gp_data_size': 256, 'normalize_xs': True, 'normalize_ys': True, 'to_logits': False, 'record_hist': True}

# %%
# toy example
# te1 

# Synthetic Functions 
# "dtlz1 dtlz2 dtlz3 dtlz4 dtlz5 dtlz6 dtlz7 zdt1 zdt2 zdt3 zdt4 zdt6 vlmop1 vlmop2 vlmop3 omnitest"

# RE
# "re21 re22 re23 re24 re25 re31 re32 re33 re34 re35 re36 re37 re41 re42 re61"

# MO-NAS
# "nb201_test c10mop1 c10mop2 c10mop3 c10mop4 c10mop5 c10mop6 c10mop7 c10mop8 c10mop9 in1kmop1 in1kmop2 in1kmop3 in1kmop4 in1kmop5 in1kmop6 in1kmop7 in1kmop8 in1kmop9"

# MORL
# "mo_hopper_v2 mo_swimmer_v2"

# MOCO 
# "bi_tsp_20 bi_tsp_50 bi_tsp_100 bi_tsp_500 tri_tsp_20 tri_tsp_50 tri_tsp_100 bi_cvrp_20 bi_cvrp_50 bi_cvrp_100 bi_kp_50 bi_kp_100 bi_kp_200"

# Scientific Design
# "zinc regex rfp molecule"

# %%
# from utils import process_args 
# sys.argv = ['--model=End2End', '--train_mode=Vallina','--task=re21','--use_wandb=False','--n_epochs=10','--retrain_model=False','--seed=1000']
# config = process_args(return_dict=True)

# results_dir = os.path.join('/home/tzhouaq/offline-moo/', "results")
# model_save_dir = os.path.join('/home/tzhouaq/offline-moo/', "model")
 
# config["results_dir"] = results_dir
# config["model_save_dir"] = model_save_dir
# config["data_pruning"] = True
# config['data_preserved_ratio']= 1.0
# config['hidden_size']=2048
# config['inverse_lr']=1e-4
# # config['batch_size']= 16
# config['inverse_lr_decay']=0.98
# config['n_epochs']= 200

# config['simple_clip']=True
# config['debais']=True
# config["record_hist"]=False
# config['dropout']=0. 
# config['augment']=True
# config['condition_training']=False
# config['model_ckpt'] = None 
# # config['normalize_xs'] = False
# # config['normalize_ys'] = False

# %%
import os 
import sys 
import wandb 
import torch 
import numpy as np 
import pandas as pd 
import datetime 
import json 
from copy import deepcopy

# BASE_PATH = os.path.join(
#     os.path.dirname(os.path.abspath(__file__)),
#     "..", ".."
# )
# sys.path.append(BASE_PATH)

import off_moo_bench as ob
from pymoo.algorithms.moo.nsga2 import NSGA2
from utils import set_seed, get_quantile_solutions
from off_moo_baselines.data import get_dataloader
from off_moo_baselines.mobo import get_mobo_solver
from off_moo_baselines.mobo.mobo_utils import tkwargs
from off_moo_bench.task_set import *
from off_moo_bench.evaluation.metrics import hv
from off_moo_bench.evaluation.plot import plot_y

# %%
def run(config: dict):
    if config["task"] in ALLTASKSDICT.keys():
        config["task"] = ALLTASKSDICT[config["task"]]
    
    results_dir = os.path.join(config['results_dir'], 
                               f"{config['model']}-{config['train_mode']}-{config['task']}")
    config["results_dir"] = results_dir 
    
    ts = datetime.datetime.utcnow() + datetime.timedelta(hours=+8)
    ts_name = f"-ts-{ts.year}-{ts.month}-{ts.day}_{ts.hour}-{ts.minute}-{ts.second}"
    run_name = f"{config['model']}-{config['train_mode']}-seed{config['seed']}-{config['task']}"
    
    logging_dir = os.path.join(config['results_dir'], run_name + ts_name)
    os.makedirs(logging_dir, exist_ok=True)

    if config['use_wandb']:
        if 'wandb_api' in config.keys():
            wandb.login(key=config['wandb_api'])

        wandb.init(
            project="Offline-MOO",
            name=run_name + ts_name,
            config=config,
            group=f"{config['model']}-{config['train_mode']}",
            job_type=config['run_type'],
            mode="online",
            dir=os.path.join(config['results_dir'], '..')
        )
    
    with open(os.path.join(logging_dir, "params.json"), "w") as f:
        json.dump(config, f, indent=4)

    set_seed(config['seed'])

    task = ob.make(config['task'])
    pf = task.problem.get_pareto_front()
    if config['normalize_ys']:
        pf = task.normalize_y(pf)
    X = task.x.copy()
    y = task.y.copy()
    
    if config["data_pruning"]:
        X, y = task.get_N_non_dominated_solutions(
            N=int(X.shape[0] * config["data_preserved_ratio"]),
            return_x=True, return_y=True
        )
    
    X_test = task.x_test.copy()
    y_test = task.y_test.copy()
    
    if config['to_logits']:
        assert task.is_discrete 
        task.map_to_logits()
        X = task.to_logits(X)
        X_test = task.to_logits(X_test)
    if config['normalize_xs']:
        task.map_normalize_x()
        X = task.normalize_x(X)
        X_test = task.normalize_x(X_test)
    if config['normalize_ys']:
        task.map_normalize_y()
        y = task.normalize_y(y)
        y_test = task.normalize_y(y_test)
    
    if config['to_logits']:
        data_size, n_dim, n_classes = tuple(X.shape)
        X = X.reshape(-1, n_dim * n_classes)
        X_test = X_test.reshape(-1, n_dim * n_classes)
    else:
        data_size, n_dim = tuple(X.shape)
    n_obj = y.shape[1]
        
    model_save_dir = config['model_save_dir']
    os.makedirs(model_save_dir, exist_ok=True)
    
    MOBO_Solver = get_mobo_solver(config["train_mode"])\
        (
            config=config,
            X_init=torch.Tensor(X).to(**tkwargs),
            Y_init=torch.Tensor(y).to(**tkwargs),
            solver_kwargs={
                "ref_point": torch.Tensor(1.1 * task.nadir_point).to(**tkwargs),
                "xl": task.xl,
                "xu": task.xu,
            },
            train_gp_data_size=config["train_gp_data_size"],
            output_size=config["num_solutions"],
            negate=True
        )
    
    res_x = MOBO_Solver.run()
    if config['to_logits']:
        res_x = res_x.reshape(-1, n_dim, n_classes)
    if config['normalize_xs']:
        task.map_denormalize_x()
        res_x = task.denormalize_x(res_x)
    if config['to_logits']:
        task.map_to_integers()
        res_x = task.to_integers(res_x)
    
    res_y = task.predict(res_x)
    visible_masks = np.ones(len(res_y))
    visible_masks[np.where(np.logical_or(np.isinf(res_y), np.isnan(res_y)))[0]] = 0
    visible_masks[np.where(np.logical_or(np.isinf(res_x), np.isnan(res_x)))[0]] = 0
    res_x = res_x[np.where(visible_masks == 1)[0]]
    res_y = res_y[np.where(visible_masks == 1)[0]]
    
    res_y_75_percent = get_quantile_solutions(res_y, 0.75)
    res_y_50_percent = get_quantile_solutions(res_y, 0.50)
    
    nadir_point = task.nadir_point
    if config['normalize_ys']:
        res_y = task.normalize_y(res_y)
        nadir_point = task.normalize_y(nadir_point)
        res_y_50_percent = task.normalize_y(res_y_50_percent)
        res_y_75_percent = task.normalize_y(res_y_75_percent)
        
    _, d_best = task.get_N_non_dominated_solutions(
        N=6000, 
        return_x=False, return_y=True
    )
    
    np.save(file=os.path.join(logging_dir, "res_x.npy"), arr=res_x)
    np.save(file=os.path.join(logging_dir, "res_y.npy"), arr=res_y)
    plot_y(res_y, save_dir=logging_dir, config=config,
           nadir_point=nadir_point, d_best=d_best, pareto_front=pf,)
        
    d_best_hv = hv(nadir_point, d_best, config['task'])
    hv_value = hv(nadir_point, res_y, config['task'])
    hv_value_50_percentile = hv(nadir_point, res_y_50_percent, config['task'])
    hv_value_75_percentile = hv(nadir_point, res_y_75_percent, config['task'])
    
    print(f"Hypervolume (100th): {hv_value:4f}")
    print(f"Hypervolume (75th): {hv_value_75_percentile:4f}")
    print(f"Hypervolume (50th): {hv_value_50_percentile:4f}")
    print(f"Hypervolume (D(best)): {d_best_hv:4f}")


    # 假设 pf 是你的帕累托前沿
    ind_gd = GD(pf)
    ind_gdp = GDPlus(pf)
    ind_igd = IGD(pf)
    ind_igdp = IGDPlus(pf)

    # 计算 MOO的各种 指标
    gd_plus_value = ind_gd.do(res_y)
    gdp_plus_value = ind_gdp.do(res_y)
    igd_value = ind_igd.do(res_y)
    igd_plus_value = ind_igdp.do(res_y)

    print("GD:", gd_plus_value)
    print("GD+:", gdp_plus_value)
    print("IGD:", igd_value)
    print("IGD+:", igd_plus_value)
    indicators_results = {
        "GD": gd_plus_value,
        "GD+": gd_plus_value,
        "IGD": igd_value,
        "IGD+": igd_plus_value,
    }
    hv_results = {
        "hypervolume/D(best)": d_best_hv,
        "hypervolume/100th": hv_value, 
        "hypervolume/75th": hv_value_75_percentile,
        "hypervolume/50th": hv_value_50_percentile,
        "evaluation_step": 1,
    }

    indicators_results.update(hv_results)

 
    
    df = pd.DataFrame([hv_results])
    filename = os.path.join(logging_dir, "hv_results.csv")
    df.to_csv(filename, index=False)
    
    if config["use_wandb"]:
        wandb.log(hv_results)

    return hv_value, igd_value

# %%
     

from utils import process_args 
config = process_args(return_dict=True)

results_dir = os.path.join(BASE_PATH, "results")
model_save_dir = os.path.join(BASE_PATH, "model")

config["results_dir"] = results_dir
config["model_save_dir"] = model_save_dir

config["train_gp_data_size"] = 256

solutions = []
run_trials = 4
seed_list = [40,41,42,43]
HV_list = []
IGD_list = []
for seed in seed_list:
    print(f"******************************************Seed{seed}****************************************************")
    config['seed'] = seed
    hv_value, igd_value = run(config)
    HV_list.append(hv_value)
    IGD_list.append(igd_value)
# Out:
# All config: {'results_dir': './results', 'model_save_dir': './model', 'use_wandb': False, 'run_type': 'train', 'seed': 1000, 'retrain_model': False, 'num_solutions': 256, 'solver_n_gen': 50, 'solver_init_method': 'nds', 'model': 'MOBO', 'train_mode': 'Vallina', 'task': 're31', 'n_epochs': 10, 'data_pruning': False, 'permutation_n_gen': 200, 'sequence_n_gen': 200, 'train_gp_data_size': 256, 'normalize_xs': True, 'normalize_ys': True, 'to_logits': False, 'record_hist': True}
# ******************************************Seed40****************************************************
# Hypervolume (100th): 10.434949
# Hypervolume (75th): 10.434949
# Hypervolume (50th): 9.854224
# Hypervolume (D(best)): 10.607175
# GD: 0.04944525979332155
# GD+: 0.04017554456441276
# IGD: 0.2237535780925306
# IGD+: 0.02707480414677045
# ******************************************Seed41****************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 20
#      18 print(f"******************************************Seed{seed}****************************************************")
#      19 config['seed'] = seed
# ---> 20 hv_value, igd_value = run(config)
#      21 HV_list.append(hv_value)
#      22 IGD_list.append(igd_value)
#
# Cell In[6], line 91, in run(config)
#      74 os.makedirs(model_save_dir, exist_ok=True)
#      76 MOBO_Solver = get_mobo_solver(config["train_mode"])\
#      77     (
#      78         config=config,
#    (...)
#      88         negate=True
#      89     )
# ---> 91 res_x = MOBO_Solver.run()
#      92 if config['to_logits']:
#      93     res_x = res_x.reshape(-1, n_dim, n_classes)
#
# File ~/offline-moo/off_moo_baselines/mobo/mobo_vallina.py:270, in MOBOVallina.run(self)
#     269 def run(self) -> ndarray:
# --> 270     return self.solver.run()
#
# File ~/offline-moo/off_moo_baselines/mobo/mobo_vallina.py:105, in MOBOContinuous.run(self)
#      93 partitioning = FastNondominatedPartitioning(
#      94     ref_point=torch.zeros_like(self.ref_point, device=self.ref_point.device, dtype=self.ref_point.dtype),
#      95     Y=pred,
#      96 )
#      97 acq_func = qNoisyExpectedHypervolumeImprovement(
#      98     model=model,
#      99     ref_point=self.ref_point,
#    (...)
#     102     sampler=sampler,
#     103 )
# --> 105 candidates, _ = optimize_acqf(
#     106     acq_function=acq_func,
#     107     bounds=standard_bounds,
#     108     q=self.output_size,
#     109     num_restarts=NUM_RESTARTS,
#     110     raw_samples=RAW_SAMPLES,
#     111     options={"batch_limit": 10, "maxiter": 200},
#     112     sequential=True,
#     113 )
#     115 candidates = unnormalize(candidates.detach(), bounds=self.bounds)
#     116 return candidates.cpu().numpy()
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/optim/optimize.py:544, in optimize_acqf(acq_function, bounds, q, num_restarts, raw_samples, options, inequality_constraints, equality_constraints, nonlinear_inequality_constraints, fixed_features, post_processing_func, batch_initial_conditions, return_best_only, gen_candidates, sequential, ic_generator, timeout_sec, return_full_tree, retry_on_optimization_warning, **ic_gen_kwargs)
#     521     gen_candidates = gen_candidates_scipy
#     522 opt_acqf_inputs = OptimizeAcqfInputs(
#     523     acq_function=acq_function,
#     524     bounds=bounds,
#    (...)
#     542     ic_gen_kwargs=ic_gen_kwargs,
#     543 )
# --> 544 return _optimize_acqf(opt_acqf_inputs)
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/optim/optimize.py:566, in _optimize_acqf(opt_inputs)
#     564 # Perform sequential optimization via successive conditioning on pending points
#     565 if opt_inputs.sequential and opt_inputs.q > 1:
# --> 566     return _optimize_acqf_sequential_q(
#     567         opt_inputs=opt_inputs,
#     568         timeout_sec=timeout_sec,
#     569         start_time=start_time,
#     570     )
#     572 # Batch optimization (including the case q=1)
#     573 return _optimize_acqf_batch(
#     574     opt_inputs=opt_inputs, start_time=start_time, timeout_sec=timeout_sec
#     575 )
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/optim/optimize.py:248, in _optimize_acqf_sequential_q(opt_inputs, timeout_sec, start_time)
#     246     acq_value_list.append(acq_value)
#     247     candidates = torch.cat(candidate_list, dim=-2)
# --> 248     new_inputs.acq_function.set_X_pending(
#     249         torch.cat([base_X_pending, candidates], dim=-2)
#     250         if base_X_pending is not None
#     251         else candidates
#     252     )
#     253     logger.info(f"Generated sequential candidate {i+1} of {opt_inputs.q}")
#     254 opt_inputs.acq_function.set_X_pending(base_X_pending)
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/acquisition/multi_objective/monte_carlo.py:670, in qNoisyExpectedHypervolumeImprovement.set_X_pending(self, X_pending)
#     668 self.register_buffer("_X_baseline_and_pending", X_baseline)
#     669 # Recompute box decompositions.
# --> 670 self._set_cell_bounds(num_new_points=num_new_points)
#     671 if not self.incremental_nehvi:
#     672     self._prev_nehvi = (
#     673         (self._hypervolumes - self._initial_hvs)
#     674         .clamp_min(0.0)
#     675         .mean()
#     676     )
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/acquisition/multi_objective/monte_carlo.py:618, in qNoisyExpectedHypervolumeImprovement._set_cell_bounds(self, num_new_points)
#     616 partitionings = []
#     617 for sample in obj_cpu:
# --> 618     partitioning = self.p_class(
#     619         ref_point=ref_point_cpu, Y=sample, **self.p_kwargs
#     620     )
#     621     partitionings.append(partitioning)
#     622 self.partitioning = BoxDecompositionList(*partitionings)
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/utils/multi_objective/box_decompositions/non_dominated.py:384, in FastNondominatedPartitioning.__init__(self, ref_point, Y)
#     370 def __init__(
#     371     self,
#     372     ref_point: Tensor,
#     373     Y: Optional[Tensor] = None,
#     374 ) -> None:
#     375     """Initialize FastNondominatedPartitioning.
#     376
#     377     Args:
#    (...)
#     382         >>> bd = FastNondominatedPartitioning(ref_point, Y=Y1)
#     383     """
# --> 384     super().__init__(ref_point=ref_point, Y=Y)
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/utils/multi_objective/box_decompositions/box_decomposition.py:274, in FastPartitioning.__init__(self, ref_point, Y)
#     264 def __init__(
#     265     self,
#     266     ref_point: Tensor,
#     267     Y: Optional[Tensor] = None,
#     268 ) -> None:
#     269     """
#     270     Args:
#     271         ref_point: A `m`-dim tensor containing the reference point.
#     272         Y: A `(batch_shape) x n x m`-dim tensor
#     273     """
# --> 274     super().__init__(ref_point=ref_point, Y=Y, sort=ref_point.shape[-1] == 2)
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/utils/multi_objective/box_decompositions/box_decomposition.py:67, in BoxDecomposition.__init__(self, ref_point, sort, Y)
#      65     self._validate_inputs()
#      66     self._neg_pareto_Y = self._compute_pareto_Y()
# ---> 67     self.partition_space()
#      68 else:
#      69     self._neg_Y = None
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/utils/multi_objective/box_decompositions/box_decomposition.py:325, in FastPartitioning.partition_space(self)
#     323     self._get_single_cell()
#     324 else:
# --> 325     super().partition_space()
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/utils/multi_objective/box_decompositions/box_decomposition.py:151, in BoxDecomposition.partition_space(self)
#     149         self._partition_space()
#     150 else:
# --> 151     self._partition_space()
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/utils/multi_objective/box_decompositions/box_decomposition.py:363, in FastPartitioning._partition_space(self)
#     356 # incrementally update local upper bounds and defining points
#     357 # for each new Pareto point
#     358 self._U, self._Z = update_local_upper_bounds_incremental(
#     359     new_pareto_Y=self._neg_pareto_Y,
#     360     U=self._U,
#     361     Z=self._Z,
#     362 )
# --> 363 self._get_partitioning()
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/utils/multi_objective/box_decompositions/non_dominated.py:424, in FastNondominatedPartitioning._get_partitioning(self)
#     421     self._Z2[0, j, j] = self._U2[0, j]
#     422 # incrementally update local upper bounds and defining points
#     423 # for each new Pareto point
# --> 424 self._U2, self._Z2 = update_local_upper_bounds_incremental(
#     425     new_pareto_Y=-self._U,
#     426     U=self._U2,
#     427     Z=self._Z2,
#     428 )
#     429 cell_bounds = get_partition_bounds(
#     430     Z=self._Z2, U=self._U2, ref_point=new_ref_point.view(-1)
#     431 )
#     432 self.hypercell_bounds = cell_bounds
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/utils/multi_objective/box_decompositions/utils.py:218, in update_local_upper_bounds_incremental(new_pareto_Y, U, Z)
#     201 r"""Update the current local upper with the new pareto points.
#     202
#     203 This assumes minimization.
#    (...)
#     215     - A `n' x m x m`-dim tensor containing the defining points
#     216 """
#     217 for i in range(new_pareto_Y.shape[-2]):
# --> 218     U, Z = compute_local_upper_bounds(U=U, Z=Z, z=new_pareto_Y[i])
#     219 return U, Z
#
# File ~/anaconda3/envs/off-moo/lib/python3.8/site-packages/botorch/utils/multi_objective/box_decompositions/utils.py:136, in compute_local_upper_bounds(U, Z, z)
#     134 for j in range(num_outcomes):
#     135     mask[j] = 0
# --> 136     z_uj_max = A_Z[:, mask, j].max(dim=-1).values.view(-1)
#     137     add_z = z[j] >= z_uj_max
#     138     if add_z.any():
#
# KeyboardInterrupt:

# %%
print(f"Average Hypervolume: {np.mean(HV_list)}, std: {np.std(HV_list)}")
print(f"Average IGD: {np.mean(IGD_list)}, std: {np.std(IGD_list)}")
# Out:
# Average Hypervolume: 10.434948570737435, std: 0.0
# Average IGD: 0.2237535780925306, std: 0.0

# %%
     

from utils import process_args 
config = process_args(return_dict=True)

results_dir = os.path.join(BASE_PATH, "results")
model_save_dir = os.path.join(BASE_PATH, "model")

config["results_dir"] = results_dir
config["model_save_dir"] = model_save_dir

config["train_gp_data_size"] = 1

solutions = []
run_trials = 4
HV_list = []
IGD_list = []
seed_list = [40]
for seed in seed_list:
    print(f"******************************************Seed{seed}****************************************************")
    config['seed'] = seed
    hv_value, igd_value = run(config)
    HV_list.append(hv_value)
    IGD_list.append(igd_value)
# Out:
# All config: {'results_dir': './results', 'model_save_dir': './model', 'use_wandb': False, 'run_type': 'train', 'seed': 1000, 'retrain_model': False, 'num_solutions': 256, 'solver_n_gen': 50, 'solver_init_method': 'nds', 'model': 'MOBO', 'train_mode': 'Vallina', 'task': 're31', 'n_epochs': 10, 'data_pruning': False, 'permutation_n_gen': 200, 'sequence_n_gen': 200, 'train_gp_data_size': 256, 'normalize_xs': True, 'normalize_ys': True, 'to_logits': False, 'record_hist': True}
# ******************************************Seed40****************************************************

# %%
print(f"Average Hypervolume: {np.mean(HV_list)}, std: {np.std(HV_list)}")
print(f"Average IGD: {np.mean(IGD_list)}, std: {np.std(IGD_list)}")
# Out:
# Average Hypervolume: nan, std: nan
# Average IGD: nan, std: nan
